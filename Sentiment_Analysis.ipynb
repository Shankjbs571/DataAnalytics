# %% [markdown]
# <a href="https://colab.research.google.com/github/Shankjbs571/DataAnalytics/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import spacy
from textblob import TextBlob
from sklearn.metrics import classification_report

# %%
data = pd.read_csv('/content/senti-tilte.csv')
data['TextBlob_Subjectivity'] = data['original_title'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
data['TextBlob_Polarity'] = data['original_title'].apply(lambda x: TextBlob(x).sentiment.polarity)
data['TextBlob_Analysis'] = data['TextBlob_Polarity'].apply(lambda x: 'negative' if x<0 else 'positive')
# data.head()
print(data)
# Out:
#                                 original_title
# 0                             The Hunger Games
# 1     Harry Potter and the Philosopher's Stone
# 2                                     Twilight
# 3                       The Fault in Our Stars
# 4                                    Divergent
# ...                                        ...
# 1297                             City of Masks
# 1298                                  Promised
# 1299                           Dangerous Girls
# 1300                                   Magonia
# 1301                                Wild Cards
#
# [1302 rows x 1 columns]

# %%
data1 = pd.read_csv('/content/senti-tilte.csv')

# Drop rows with any NaN (empty) values
data_cleaned = data1.dropna()

# If you want to remove rows where specific columns are empty, you can do:
data_cleaned = data.dropna(subset=['original_title'])

# Print the cleaned DataFrame
print(data_cleaned)
# Save the cleaned DataFrame to a new CSV file
data_cleaned.to_csv('/content/senti-tilte_cleaned.csv', index=False)
# Out:
#                                 original_title
# 0                             The Hunger Games
# 1     Harry Potter and the Philosopher's Stone
# 2                                     Twilight
# 3                       The Fault in Our Stars
# 4                                    Divergent
# ...                                        ...
# 1297                             City of Masks
# 1298                                  Promised
# 1299                           Dangerous Girls
# 1300                                   Magonia
# 1301                                Wild Cards
#
# [1302 rows x 1 columns]

# %%
data['TextBlob_Subjectivity'] = data['original_title'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
data['TextBlob_Polarity'] = data['original_title'].apply(lambda x: TextBlob(x).sentiment.polarity)
data['TextBlob_Analysis'] = data['TextBlob_Polarity'].apply(lambda x: 'negative' if x<0 else 'positive')

# %%
data['TextBlob_Analysis'] = data['TextBlob_Polarity'].apply(lambda x: 'negative' if x<0 else 'positive')

# %%
data
# Out:
#                                 original_title  TextBlob_Subjectivity  \
# 0                             The Hunger Games                    0.0
# 1     Harry Potter and the Philosopher's Stone                    0.0
# 2                                     Twilight                    0.0
# 3                       The Fault in Our Stars                    0.0
# 4                                    Divergent                    0.0
# ...                                        ...                    ...
# 1297                             City of Masks                    0.0
# 1298                                  Promised                    0.0
# 1299                           Dangerous Girls                    0.9
# 1300                                   Magonia                    0.0
# 1301                                Wild Cards                    0.4
#
#       TextBlob_Polarity TextBlob_Analysis
# 0                   0.0          positive
# 1                   0.0          positive
# 2                   0.0          positive
# 3                   0.0          positive
# 4                   0.0          positive
# ...                 ...               ...
# 1297                0.0          positive
# 1298                0.0          positive
# 1299               -0.6          negative
# 1300                0.0          positive
# 1301                0.1          positive
#
# [1302 rows x 4 columns]

# %%
positive_titles_count = data[data['TextBlob_Analysis'] == 'positive'].shape[0]

print(f"The number of original titles with a 'positive' sentiment is: {positive_titles_count}")
# Out:
# The number of original titles with a 'positive' sentiment is: 1191
